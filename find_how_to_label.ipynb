# %%
import re

from sklearn.feature_extraction.text import CountVectorizer

# %%
texts = []

related_company = ['효성', '더클래스효성', '에이에스씨', '효성티앤에스', '진흥기업', '효성아이티엑스','효성itx', '에프엠케이','FMK', '효성굿스프링스', '효성캐피탈', '효성인포메이션시스템', '효성트랜스월드', '갤럭시아디바이스', '신화인터텍', '신성자동차', '효성토요타', '신동진', '갤럭시아커뮤니케이션즈', '더프리미엄효성', '갤럭시아일렉트로닉스', '엔에이치테크', '갤럭시아에스엠', '엔에이치씨엠에스', '갤럭시아코퍼레이션', '효성에프엠에스', '효성프리미어모터스', '아이티엑스마케팅', '평창풍력발전', '세빛섬', '공덕개발', '광주일보사', '공덕경우개발', '트리니티에셋매니지먼트', '에이티엠플러스', '행복두드리미', '태안솔라팜', '에브리쇼', '동륭실업', '아승오토모티브그룹', '효성투자개발', '효성중공업']

with open('/Users/len/kamill/tests/textures/sentences.txt', 'r', encoding='utf8') as input_file:
    for index, line in enumerate(input_file):
        line = re.sub('[^\w]', ' ', line)
        words = [word for word in line.split() if '효성' in word]
        new_str = ' '.join(words)
        texts.append(new_str)

vect = CountVectorizer(ngram_range=(1, 1))
matrix = vect.fit_transform(texts)
# Out:
# {'실효성에도': 156,
#  '실효성은': 160,
#  '실효성이': 164,
#  '효성의': 631,
#  '효성이다': 634,
#  '효성은': 629,
#  '효성': 366,
#  '전효성이': 315,
#  '실효성': 133,
#  '효성을': 630,
#  '효성이': 632,
#  '효성itx는': 378,
#  '실효성에': 153,
#  '효성도': 511,
#  '효성그룹이': 458,
#  '유효성이': 273,
#  '지효성': 334,
#  '실효성이다': 166,
#  '실효성을': 161,
#  '노틸러스효성이': 47,
#  '유효성은': 270,
#  '실효성및': 146,
#  '약효성을': 202,
#  '유효성에': 265,
#  '효성그룹': 443,
#  '유효성을': 271,
#  '실효성도': 142,
#  '효성해링턴': 769,
#  '더클래스효성에서는': 61,
#  '효성그룹의': 457,
#  '효성중공업': 686,
#  '효성물산을': 537,
#  '효성에': 585,
#  '효성그룹은': 455,
#  '효성병원': 549,
#  '규제실효성': 29,
#  '효성오앤비': 610,
#  '효성증권이': 697,
#  '유효성분': 238,
#  '유효성이나': 274,
#  '이효성': 286,
#  '전효성은': 312,
#  '전효성을': 313,
#  '효성과': 429,
#  '효성캐피탈에서는': 718,
#  '전효성의': 314,
#  '효성그룹에': 450,
#  '실효성과': 139,
#  '효성itx와': 387,
#  '효성가의': 415,
#  '효성itx': 374,
#  '실효성엔': 158,
#  '효성itx가': 376,
#  '효성에서만': 592,
#  '효성프리미어모터스': 759,
#  '실효성의': 162,
#  '유효성분인': 259,
#  '효성그룹과': 445,
#  '효성캐피탈': 711,
#  '효성인': 642,
#  '실효성뿐': 151,
#  '실효성이라는': 169,
#  '오토밸리로효성해링턴플레이스': 209,
#  '유효성': 224,
#  '실효성있는': 175,
#  '효성캐피탈로부터': 715,
#  '효성창조경제펀드에서': 702,
#  '효성오앤비는': 612,
#  '유효성분을': 256,
#  '효성에게': 586,
#  '효성itx의': 390,
#  '즉효성과': 332,
#  '전효성': 304,
#  '효성인으로서의': 651,
#  '효성전기는': 669,
#  '임효성씨는': 298,
#  '효성회장을': 801,
#  '효성랑카공장에서': 527,
#  '유효성과': 232,
#  '더프리미엄효성은': 67,
#  '효성물산은': 536,
#  '효성itx도': 379,
#  '정효성': 324,
#  '효성인력개발원': 644,
#  '조효성': 328,
#  '효성오앤비의': 616,
#  '노틸러스효성은': 44,
#  '효성해링턴플레이스는': 787,
#  '효성그룹도': 448,
#  '효성해링턴플레이스와': 790,
#  '효성그룹엔': 453,
#  '효성만이': 531,
#  '임효성': 295,
#  '유효성도': 235,
#  '효성빌라의': 567,
#  '효성해링턴플레이스': 784,
#  '효성해링턴코트는': 774,
#  '효성프리미어모터스가': 760,
#  '안정화효성그룹이': 192,
#  '효성여대가': 606,
#  '효성에서': 589,
#  '효성나눔봉사단': 486,
#  '효성기술원을': 477,
#  '전효성이다': 316,
#  '효성가는': 413,
#  '효성전기가': 668,
#  '효성itx사업장': 383,
#  '전효성이라고': 317,
#  '효성웨이': 619,
#  '효성usa의': 398,
#  '유효성분이': 258,
#  '효성증권': 696,
#  '유효성분의': 257,
#  '효성사태': 574,
#  '효성그': 442,
#  '효성중공업은': 692,
#  '효성투자개발이': 749,
#  '효성그룹에서는': 452,
#  '효성해링턴타워': 777,
#  '효성캐피탈의': 721,
#  '효성측은': 707,
#  '개성토건ㆍ미주산업ㆍ효성ㆍ롯데쇼핑': 16,
#  '효성으로부터': 627,
#  '효성캠': 725,
#  '효성그룹과의': 447,
#  '집중효성': 337,
#  '효성가': 412,
#  '효성으로': 626,
#  '실효성에는': 155,
#  '효성등은': 524,
#  '실효성현': 178,
#  '효성오앤비가': 611,
#  '유효성분으로': 252,
#  '효성1호점에서': 370,
#  '효성이란': 637,
#  '유효성분까지': 241,
#  '효성토요타': 737,
#  '효성주': 677,
#  '실효성이나': 165,
#  '안전성ㆍ유효성': 183,
#  '범어효성해링턴플레이스': 102,
#  '범어동효성해링턴플레이스': 100,
#  '효성오앤비와': 615,
#  '효성건설pu는': 420,
#  '효성해링턴코트': 773,
#  '유효성분과': 240,
#  '실효성까지': 140,
#  '효성동에': 519,
#  '효성표': 756,
#  '부사장효성은': 107,
#  '효성해링턴플': 781,
#  '효성웨이는': 620,
#  '효성인포메이션시스템은': 659,
#  '효성시티병원': 580,
#  '청주효성병원은': 343,
#  '효성usa가': 395,
#  '효성처럼': 703,
#  '제공효성은': 325,
#  '효성나눔봉사단장': 496,
#  '효성itx를': 382,
#  '효성ㆍ진흥기업은': 407,
#  '미사역효성해링턴': 84,
#  '전효성과': 305,
#  '발효성분과': 91,
#  '효성짬뽕': 701,
#  '효성ㆍ진흥기업': 406,
#  '유효성분만을': 248,
#  '효성it와': 391,
#  '효성토요타도': 739,
#  '더클래스효성의': 64,
#  '유효성분에': 250,
#  '효성물산의': 538,
#  '기업들효성은': 31,
#  '효성해링턴플레': 782,
#  '효성탄소특화창업보육센터에': 736,
#  '실효성보다는': 148,
#  '특별법은실효성': 350,
#  '유효성분에는': 251,
#  '전복발효성분으로': 303,
#  '실효성부터': 150,
#  '효성사': 569,
#  '원효성': 218,
#  '노틸러스효성에서': 43,
#  '효성베트남': 546,
#  '효성usa는': 396,
#  '효성중에': 694,
#  '효성종합의': 676,
#  '효성탄소특화창업보육센터': 735,
#  '효성캐피탈에': 716,
#  '더클래스효성': 58,
#  '효성itx에': 385,
#  '전효성만의': 308,
#  '효성이엔지는': 639,
#  '강남효성해링턴코트': 12,
#  '효성해링': 768,
#  '슈ㆍ임효성': 125,
#  '유효성분명으로': 249,
#  '현대bf94효성콜': 359,
#  '효성남초ㆍ효성동초ㆍ명현중ㆍ효성고': 506,
#  '효성빌라는': 565,
#  '효성빌라': 563,
#  '효성여대': 605,
#  '발효성분을': 92,
#  '효성엔지니어링': 596,
#  '효성코아': 731,
#  '효성건설은': 424,
#  '효성해링텅': 793,
#  '효성병원을': 553,
#  '효성기술원에서': 475,
#  '효성건설의': 425,
#  '효성동': 516,
#  '효성중공업pg가': 688,
#  '효성윈드파워홀딩스의': 624,
#  '무궁화효성이': 77,
#  '효성1호점에': 369,
#  '효성에도': 588,
#  '효성물산': 533,
#  '효성엔지니어링을': 601,
#  '현대자동차ㆍlgㆍ효성그룹': 361,
#  '효성건설pu': 419,
#  '노틸러스효성': 39,
#  '효성컨테이너의': 730,
#  '효성기술원은': 476,
#  '유효성분은': 255,
#  '효성해링턴플레이': 783,
#  '실효성없는': 152,
#  '효성에서는': 590,
#  '효성원룸': 618,
#  '효성빌라를': 566,
#  '전효성에게': 311,
#  '유효성분들이': 245,
#  '효성캠퍼스': 726,
#  '효성인포메이션시스템': 658,
#  '대상ㆍ효성ㆍ': 54,
#  '효성캐피탈을': 720,
#  '효성전기의': 671,
#  '안전ㆍ유효성': 181,
#  '효성캐피탈은': 719,
#  '효성웨이를': 621,
#  '유효성부터': 237,
#  '김효성': 32,
#  '노틸러스효성의': 46,
#  '효성종합건설은': 674,
#  '효성프리미어모터스는': 761,
#  '더클래스효성과': 59,
#  '효성도요타': 514,
#  'sk네트웍스ㆍ한국타이어ㆍ효성': 3,
#  '효성해링턴플레이스1': 785,
#  '효성나눔봉사단의': 494,
#  '발효성분이': 93,
#  '효성중': 685,
#  '꿈의숲효성해링턴플레이스': 33,
#  '미백유효성분인': 81,
#  '효성itx로': 381,
#  '효성itx노': 377,
#  '실효성ㆍ형평성': 138,
#  '약효성분을': 199,
#  '참여효성': 339,
#  '유효성검사와': 231,
#  '범효성': 103,
#  '효성전기': 667,
#  '효성기술원이라': 480,
#  '효성빌라가': 564,
#  '효성파워택': 751,
#  '효성분이': 561,
#  '효성이엔지': 638,
#  '유효성평가': 276,
#  '유효성에는': 266,
#  '효성인상': 646,
#  '효성직업전문학교': 698,
#  '효성캐피탈이': 722,
#  '평택효성해링턴플레이스': 353,
#  '효성직원이': 700,
#  '효성나눔봉사단은': 491,
#  '청주효성병원과': 342,
#  '효성해링턴스퀘어도': 771,
#  '효성노틸러스의': 509,
#  '약효성분의': 200,
#  '무효성을': 79,
#  '효성나눔봉사단장이': 501,
#  '효성오앤비다': 613,
#  '효성기술': 470,
#  '효성주식을': 679,
#  '효성fms는': 373,
#  '효성주얼리시티': 680,
#  '효성나눔봉사단장을': 500,
#  '효성usa': 394,
#  '효성기술원': 473,
#  '실효성이라고는': 168,
#  '효성나눔봉사단원들은': 487,
#  '효성비자금': 562,
#  '초속효성': 344,
#  '효성굿스프링스는': 437,
#  '전효성스러운': 309,
#  '효성나눔봉사단원이': 490,
#  '효성물산에서': 534,
#  '스효성은': 127,
#  '효성t': 393,
#  '효성인의': 654,
#  '효성엔': 594,
#  '전효성도': 306,
#  '효성어린이공원은': 584,
#  '효성家': 410,
#  '효성토요타로부터': 741,
#  '더프리미엄효성': 66,
#  '효성해링턴스퀘어': 770,
#  '노틸러스효성과': 40,
#  '용산센트럴파크효성해링턴': 211,
#  '효성그룹섬유': 449,
#  '지효성도': 335,
#  '공주신관동효성해링턴플레이스': 24,
#  '효성itx은': 389,
#  '원효성지': 219,
#  '효성과의': 431,
#  '효성그룹주에': 461,
#  '효성종합': 673,
#  '효성기계로': 468,
#  '효성이라는': 636,
#  '효성건설이': 426,
#  '효성nas': 392,
#  '효성사장': 571,
#  '효성1호점': 368,
#  '효성나눔봉사단을': 492,
#  '효성그룹에서': 451,
#  '효성나눔봉사단장인': 503,
#  '선명효성종합은': 118,
#  '효성토요타가': 738,
#  '프리미엄효성에도': 356,
#  '효성백년가약': 544,
#  '유효성분들을': 243,
#  '울산명촌의효성해링턴플레이스가': 217,
#  '효성중공업의': 693,
#  '효성플레이스': 765,
#  '안정성ㆍ유효성을': 190,
#  '유효성ㆍ안전성': 225,
#  '효성건설에서': 423,
#  '틸러스효성': 351,
#  '효성건설': 418,
#  '효성기술원의': 478,
#  '효성에서도': 591,
#  '효성홀딩스': 796,
#  '방송캡쳐임효성은': 95,
#  '효성산업자재pg의': 576,
#  '효성캐피탈과': 713,
#  '남통효성변압기공장에서': 38,
#  '효성그룹주': 459,
#  '사장효성은': 112,
#  '태전효성': 348,
#  '효성투자개발': 744,
#  '임효성과의': 297,
#  '효성그룹으로': 454,
#  '효성엔지니어링은': 600,
#  '전효성에': 310,
#  '효성대로': 510,
#  '효성나눔봉사단을설립': 493,
#  '효성이라': 635,
#  '강남역효성해링턴타워': 10,
#  '비하효성1차아파트': 110,
#  '효성주식': 678,
#  '속효성': 120,
#  '전효성전효성의': 319,
#  '효성계열사': 427,
#  '전효성만을': 307,
#  '행남자기ㆍ효성': 358,
#  '효성토요타로': 740,
#  '효성캐피탈에서': 717,
#  '효성측의': 708,
#  '효성팀은': 750,
#  '효성나눔봉사단원들이': 488,
#  '유효성확인코드인': 282,
#  'exidㆍ전효성ㆍ스누퍼': 0,
#  '유효성에서도': 268,
#  '역효성해링턴타워': 203,
#  '효성병원은': 552,
#  '더클래스효성은': 63,
#  '효성건설도': 422,
#  '임효성씨에': 299,
#  '효성인상은': 647,
#  '효성여고': 603,
#  '효성해링턴플레이스가': 786,
#  '스웨거x전효성': 126,
#  '대효성': 57,
#  '실효성에서': 157,
#  '주장효성은': 329,
#  '노틸러스효성에': 42,
#  '효성왕이': 617,
#  '효성랑카를': 528,
#  '효성아파트와': 583,
#  '실효성ㆍ안전성을': 135,
#  '임효성과': 296,
#  '이효성은': 288,
#  '삼성ㆍ효성ㆍskㆍ한화ㆍlgㆍ한진ㆍcjㆍ한솔ㆍ대림ㆍls그룹': 116,
#  '광명역효성해링턴타워더퍼스트': 27,
#  '발효성': 88,
#  '효성물산으로': 535,
#  '효성웨이와': 622,
#  '효성초': 704,
#  '탄력유효성분을': 347,
#  '후원도효성이': 807,
#  '위례효성해링턴타워': 220,
#  '효성랑카': 525,
#  '효성이나': 633,
#  '실효성있게': 172,
#  '효성도시개발이': 513,
#  '효성기술원과': 474,
#  '효성베트남에': 547,
#  '사전유효성과': 113,
#  '유효성분만': 247,
#  '효성프리미어모터스와': 763,
#  '효성병원과': 550,
#  '효성홀딩스와': 797,
#  '효성캐피': 710,
#  '효성홀딩스의': 798,
#  '효성해링턴타워가': 778,
#  '남통효성변압기공장': 37,
#  '비실효성을': 109,
#  '효성해밀턴': 794,
#  '갓효성': 8,
#  '효성프리미어모터': 758,
#  '효성캐피털': 724,
#  '동물유효성': 70,
#  '유효성분으로서': 253,
#  '실효성마저': 144,
#  '효성굿스프링스': 434,
#  '효성토요타의': 742,
#  '효성인포메이션': 656,
#  '효성등': 523,
#  '효성인포메이션은': 664,
#  '효성굿스프링스가': 435,
#  '효성풍력사업단장을': 757,
#  '효성물산이': 539,
#  '효성해링턴플레이스로': 788,
#  '영양유효성분을': 205,
#  '효성프리미어모터스를': 762,
#  '효성해링턴스퀘어와': 772,
#  '단속실효성을': 48,
#  '더클래스효성이': 65,
#  '제도실효성': 326,
#  '효성베스트빌': 545,
#  '미백유효성분의': 80,
#  '참가효성이': 338,
#  '최효성': 345,
#  '효성오앤비에': 614,
#  '효성그룹을': 456,
#  '독립성ㆍ실효성': 69,
#  '효성흑석마을': 805,
#  '효성굿윌스토어는': 441,
#  '미엄효성': 86,
#  '효성효성이': 804,
#  '미사효성해링턴타워': 85,
#  '효성있는': 666,
#  '유효성의': 272,
#  '효성여고와': 604,
#  '효성오': 609,
#  '실효성보단': 149,
#  '수입효성은': 124,
#  '정책실효성이': 323,
#  '효성타운': 733,
#  '안전성ㆍ유효성을': 186,
#  '안전성ㆍ유효성에': 185,
#  '효성투자개발에': 746,
#  '효성해링턴타워더퍼스트': 779,
#  '발효성분인': 94,
#  '정보누락ㆍ실효성': 321,
#  '효성코아와': 732,
#  '효성ㆍ전북': 403,
#  '효성맨': 532,
#  '효성나눔봉사단이': 495,
#  '효성itx에서는': 386,
#  '효성종합은': 675,
#  '안전성ㆍ유효성이': 187,
#  '효성생활산업': 577,
#  '효성측': 705,
#  '효성동에서': 521,
#  '훈련실효성을': 808,
#  '효성바스프에': 542,
#  '효성나눔봉사단장으로': 498,
#  '시효성을': 129,
#  '효성컨테이': 728,
#  '효성동에는': 520,
#  '약효성분인': 201,
#  '효성해': 767,
#  '효성나눔봉사단장은': 499,
#  '효성기술이': 484,
#  '효성itx사업장을': 384,
#  '풀고유효성이': 354,
#  '효성엔지니어링과': 599,
#  '약용유효성분을': 195,
#  '효성까지': 485,
#  '뜬다효성은': 73,
#  '효성usa법인장도': 397,
#  '효성노틸러스': 508,
#  '강변뉴타운효성해링턴플레이스': 13,
#  '용인보라효성해링턴플레이스': 213,
#  '유효성으로': 269,
#  '안정성ㆍ유효성이': 191,
#  '효성해링턴타워더퍼스트를': 780,
#  '유효성면에서도': 236,
#  '효성동나이': 518,
#  '효성주얼리시티의': 684,
#  '유효성검사를': 230,
#  '용산센트럴파크효성해링턴스퀘어': 212,
#  '효성파워택은': 752,
#  '효성굿스프링스과': 436,
#  '효성인포메이션시스템이다': 663,
#  '핵심유효성분으로': 357,
#  '상도동효성해링턴플레이스': 117,
#  '효성인으로': 649,
#  '효성가톨릭대': 416,
#  '효성기계공업으로': 467,
#  '발효성능과': 89,
#  '강남원효성빌라가': 11,
#  '유효성시험': 263,
#  '효성기': 465,
#  '당부이효성': 49,
#  '유효성평가센터는': 278,
#  '효성바스프': 540,
#  '효성헤링턴플레이스': 795,
#  '실효성마저도': 145,
#  '노틸러스효성을': 45,
#  '정책실효성을': 322,
#  '효성해링턴플레이스의': 791,
#  '영통로효성해링턴플레이스는지하2층': 207,
#  '실효성있나': 174,
#  '효성웨이의': 623,
#  '효성도요타의': 515,
#  '효성로에': 529,
#  '효성바스프와': 543,
#  '효성1구역': 367,
#  '임효성은': 300,
#  '영통로효성해링턴플에이스': 208,
#  '효성홍콩이': 799,
#  '남통효성변압기': 36,
#  '효성그룹주가': 460,
#  '실효성를': 143,
#  '효성회장이': 802,
#  '실효성있는지는': 177,
#  '효성바스프를': 541,
#  '효성나이트는': 505,
#  '더프리미엄효성의': 68,
#  '유력효성이': 222,
#  '실효성있고': 173,
#  '효성인력개발원은': 645,
#  '발효성분': 90,
#  '약효성분': 197,
#  '실효성ㆍ경제성을': 134,
#  '사장이효성': 111,
#  '효성투자개발은': 747,
#  '유효성평가센터': 277,
#  '구로디지털효성해링턴': 28,
#  '스효성이': 128,
#  '난퉁효성변압기공장': 34,
#  '효성회장': 800,
#  '유효성분들의': 244,
#  '효성ㆍ진흥기업이': 408,
#  '효성효': 803,
#  '효성파워택이': 753,
#  '효성굿스프링스와': 438,
#  '효성인으': 648,
#  '효성전기와': 670,
#  '효성그룹과도': 446,
#  '즉효성': 331,
#  '범어효성해링턴': 101,
#  '효성기술연구소를': 471,
#  '효성나이트': 504,
#  '효성부스': 557,
#  '효성캐피탈제십구차': 723,
#  '남통효성': 35,
#  '실효성확보': 179,
#  '제재실효성': 327,
#  '효성랑카가': 526,
#  '유효성분ㆍ제형ㆍ복약': 239,
#  '효성인은': 652,
#  '홍삼유효성분을': 363,
#  '속효성과': 121,
#  '지효성을': 336,
#  '유효성뿐만': 262,
#  '효성굿스프링스와사우디': 439,
#  '배효성의': 98,
#  '효성나눔봉사단장과': 497,
#  '반영효성이': 87,
#  '효성전시관': 672,
#  '대구효성병원과': 51,
#  '대구효성병원장': 53,
#  '변뉴타운효성해링턴플레이스': 104,
#  '유효성뿐': 261,
#  '유효성분추출물': 260,
#  '봉사도효성은': 106,
#  '효성인포메이션시스템의': 661,
#  '효성동굴다리': 517,
#  '효성으로서는': 628,
#  '효성탄소섬유공장': 734,
#  '효성측이': 709,
#  '영통로효성해링턴플레이스': 206,
#  '토요타효성이': 349,
#  '효성엔지니어링이': 602,
#  '유효성검사': 229,
#  '운영효성과': 215,
#  '효성주얼리시티에': 682,
#  '틸러스효성은': 352,
#  '효성기술은': 483,
#  '효성기계': 466,
#  '약효성분도': 198,
#  '인천효성남초': 290,
#  '유효성시험을': 264,
#  '유효성평가센터전임상연구동을': 279,
#  '프리미엄효성': 355,
#  '효성엔지니어링pu': 597,
#  '본사효성캐피탈은': 105,
#  '효성이엔지에': 640,
#  '실효성으로': 159,
#  '효성감리결과': 417,
#  '효성해링턴타우': 776,
#  '효성병원이': 554,
#  '효성여자대학교': 608,
#  '효성사건을': 570,
#  '효성기계와': 469,
#  '효성인들과의': 643,
#  'sk이노베이션ㆍlg화학ㆍ롯데케미칼ㆍ코오롱ㆍ효성ㆍ한화손해보험': 5,
#  '인천효성남초5': 291,
#  '안약유효성분인': 180,
#  '효성만의': 530,
#  '효성해링턴코트의': 775,
#  '회장효성': 365,
#  '대구효성병원': 50,
#  '효성주얼리시티에서': 683,
#  '효성여대생의': 607,
#  '효성해링턴플레이스를': 789,
#  '효성인으로서': 650,
#  '효성컨테이너는': 729,
#  '식물유효성분인': 131,
#  '유효성분들로': 242,
#  '효성그룹판': 462,
#  '효성엑센시티': 593,
#  '효성에는': 587,
#  '실효성보다': 147,
#  '인천효성중': 292,
#  '운효성해링턴플레이스': 216,
#  '안전성유효성': 188,
#  '주효효성이': 330,
#  '후보자이효성': 806,
#  '전효성이에': 318,
#  '실효성에까지': 154,
#  '유효성에서': 267,
#  '유효성분들이나': 246,
#  '효성나눔봉사단장이기도': 502,
#  '자연발효성분은': 301,
#  '실효성ㆍ적합성': 136,
#  '성장효성가': 119,
#  '미백주효성분인': 82,
#  '효성사장에게는': 572,
#  '효성중공업에서': 690,
#  '효성해링턴효성': 792,
#  '실효성있': 171,
#  '면역질환유효성평가센터와': 75,
#  '효성관계자는': 432,
#  '효성고': 428,
#  '효성엔지니어': 595,
#  'hl정의유효성과': 1,
#  '효성그룹株': 444,
#  '약효성': 196,
#  '실현성ㆍ유효성': 132,
#  '효성굿스링스는': 433,
#  '의왕백운밸리효성해링턴플레이스': 285,
#  '강효성': 14,
#  '효성인을': 653,
#  '공청회는실효성': 25,
#  '방송통신위원장이효성': 96,
#  '효성인이': 655,
#  '강남역효성해링턴': 9,
#  '효성스럽고': 579,
#  '효성육교': 625,
#  '유효성ㆍ안전성ㆍ약동학': 226,
#  '효성캐피탈도': 714,
#  '검사실효성': 18,
#  '효성중공업pg장': 689,
#  '공개실효성': 22,
#  '효성쥬얼리시티내': 695,
#  '인수효성그룹이': 289,
#  '안전성ㆍ유효성과': 184,
#  '효성투자개발을': 748,
#  '용인서천효성해링턴플레이스2차': 214,
#  '효성기술원장과': 482,
#  '치료유효성에': 346,
#  '효성그룹회장': 463,
#  '효성하나로': 766,
#  '강효성과': 15,
#  '완효성비료를': 210,
#  '유효성까지': 234,
#  '더클래스효성에': 60,
#  '효성중공업pg': 687,
#  '유효성과의': 233,
#  '효성노인문화센터에서': 507,
#  '고려효성그룹이': 20,
#  '효성엔지니어링pu로': 598,
#  '효성캠퍼스에서': 727,
#  '효성프리미어모터스와의': 764,
#  '효성본사에서': 556,
#  '유효성평가연구단장은': 280,
#  '효성동의': 522,
#  '열기효성이': 204,
#  '부영효성해링턴플레이스': 108,
#  '효성2공장': 371,
#  '효성직원들이': 699,
#  '공덕효성해링턴스퀘어': 23,
#  '화도효성해링턴플레이스': 364,
#  '효성과도': 430,
#  '효성중공업으로': 691,
#  '효성나눔봉사단원은': 489,
#  '효성그룹회장은': 464,
#  '식물유효성분': 130,
#  '효성병원에': 551,
#  '유효성정보가': 275,
#  '효성ㆍ푸르메재단': 409,
#  'sk네트웍스ㆍ한국타이어ㆍ효성ㆍ롯데': 4,
#  '윤효성이': 283,
#  '안정성ㆍ유효성': 189,
#  '실효성이라고': 167,
#  '효성분을': 560,
#  '효성기술연구원은': 472,
#  '더클래스효성와': 62,
#  '대양수력ㆍ효성ㆍ한국전력': 55,
#  '채용효성': 340,
#  '위헌소지ㆍ실효성': 221,
#  '효성인포메이션시스템이': 662,
#  '두산ㆍ효성': 72,
#  '효성캐피탈ㆍ동부메탈': 712,
#  '효성도시개발': 512,
#  '간담회이효성': 7,
#  '효성병원조차': 555,
#  '면해효성그룹': 76,
#  '동효성': 71,
#  '범어동효성': 99,
#  '유효성분으로써': 254,
#  '청주효성병원': 341,
#  '효성사장으로부터': 573,
#  '효성측에서': 706,
#  '효성분': 559,
#  '실효성이없고': 170,
#  '효성건설pu의': 421,
#  '안전성ㆍ안정성ㆍ일관성ㆍ동등성ㆍ유효성이': 182,
#  '효성인포메이션시스템을': 660,
#  '효성itx와의': 388,
#  '장효성': 302,
#  '효성기술원이': 479,
#  '효성ㆍ의왕시': 402,
#  '실효성있는지': 176,
#  '효성itxㆍ서울': 375,
#  '효성투자개발과': 745,
#  '효성굿스핑스': 440,
#  '유효성ㆍ적합성을': 228,
#  '효성ㆍ수출입은행': 400,
#  '대구효성병원은': 52,
#  '효성ㆍ진흥': 405,
#  '배효성': 97,
#  '효성패키징사업부': 754,
#  '무효성': 78,
#  '유지실효성': 223,
#  '점검실효성': 320,
#  '의견실효성': 284,
#  '알고보니효성': 194,
#  '대우건설ㆍ효성': 56,
#  '안효성': 193,
#  '유효성ㆍ안정성': 227,
#  '효성인포메이션이': 665,
#  '삼성ㆍ현대차ㆍskㆍlgㆍ한화ㆍ효성': 115,
#  '과일발효성분으로': 26,
#  '실효성의문': 163,
#  '효성ㆍ삼성전자ㆍ현대자동차': 399,
#  '효성아파트': 582,
#  '효성부회장이': 558,
#  '일관성ㆍ실효성이라는': 293,
#  '미비ㆍ실효성': 83,
#  '효성重': 411,
#  '개소노틸러스효성': 17,
#  '효성투자': 743,
#  '효성ㆍ육군': 401,
#  '곳이다효성': 21,
#  '효성변압기': 548,
#  '지속적ㆍ실효성있는': 333,
#  '효성itx라고': 380,
#  '효성기술원장': 481,
#  '기아차ㆍskㆍ효성ㆍ롯데': 30,
#  'skㆍ효성': 2,
#  '일산효성요양병원': 294,
#  '이효성에': 287,
#  '송효성': 123,
#  '효성ㆍ전북도': 404,
#  '효성인포메이션시': 657,
#  '효성가도': 414,
#  '효성서': 578,
#  '효성이지난': 641,
#  '효성아이티엑스': 581,
#  '맞대이효성': 74,
#  '노틸러스효성과의': 41,
#  '효성평가지수들이': 755,
#  '손효성': 122,
#  '삼성sdiㆍ효성': 114,
#  '효성뿐만': 568,
#  '유효성평가지수들이': 281,
#  '효성주얼리시티는': 681,
#  '실효성논란': 141,
#  'ㆍ이효성': 6,
#  '실효성ㆍ현실성': 137,
#  '효성3세': 372,
#  '검찰ㆍ효성': 19,
#  '현대차ㆍgsㆍ효성': 362,
#  '효성산업': 575,
#  '현대백화점ㆍ한진ㆍ효성': 360}

# %%
from collections import Counter
test_dict = Counter(vect.vocabulary_)
test_dict
# Out:
# Counter({'실효성에도': 156,
#          '실효성은': 160,
#          '실효성이': 164,
#          '효성의': 629,
#          '효성이다': 632,
#          '전효성이': 315,
#          '실효성': 133,
#          '효성을': 628,
#          '효성이': 630,
#          '효성itx는': 377,
#          '실효성에': 153,
#          '효성도': 510,
#          '효성그룹이': 457,
#          '유효성이': 273,
#          '지효성': 334,
#          '실효성이다': 166,
#          '실효성을': 161,
#          '노틸러스효성이': 47,
#          '유효성은': 270,
#          '실효성및': 146,
#          '약효성을': 202,
#          '유효성에': 265,
#          '효성그룹': 442,
#          '유효성을': 271,
#          '실효성도': 142,
#          '효성해링턴': 767,
#          '더클래스효성에서는': 61,
#          '효성그룹의': 456,
#          '효성중공업': 684,
#          '효성물산을': 536,
#          '효성에': 584,
#          '효성그룹은': 454,
#          '효성병원': 548,
#          '규제실효성': 29,
#          '효성오앤비': 609,
#          '효성증권이': 695,
#          '유효성분': 238,
#          '유효성이나': 274,
#          '이효성': 286,
#          '전효성은': 312,
#          '전효성을': 313,
#          '효성과': 428,
#          '효성캐피탈에서는': 716,
#          '전효성의': 314,
#          '효성그룹에': 449,
#          '실효성과': 139,
#          '효성itx와': 386,
#          '효성가의': 414,
#          '효성itx': 373,
#          '실효성엔': 158,
#          '효성itx가': 375,
#          '효성에서만': 591,
#          '효성프리미어모터스': 757,
#          '실효성의': 162,
#          '유효성분인': 259,
#          '효성그룹과': 444,
#          '효성캐피탈': 709,
#          '효성인': 640,
#          '실효성뿐': 151,
#          '실효성이라는': 169,
#          '오토밸리로효성해링턴플레이스': 209,
#          '유효성': 224,
#          '실효성있는': 175,
#          '효성캐피탈로부터': 713,
#          '효성창조경제펀드에서': 700,
#          '효성오앤비는': 611,
#          '유효성분을': 256,
#          '효성에게': 585,
#          '효성itx의': 389,
#          '즉효성과': 332,
#          '전효성': 304,
#          '효성인으로서의': 649,
#          '효성전기는': 667,
#          '임효성씨는': 298,
#          '효성회장을': 799,
#          '효성랑카공장에서': 526,
#          '유효성과': 232,
#          '더프리미엄효성은': 67,
#          '효성물산은': 535,
#          '효성itx도': 378,
#          '정효성': 324,
#          '효성인력개발원': 642,
#          '조효성': 328,
#          '효성오앤비의': 615,
#          '노틸러스효성은': 44,
#          '효성해링턴플레이스는': 785,
#          '효성그룹도': 447,
#          '효성해링턴플레이스와': 788,
#          '효성그룹엔': 452,
#          '효성만이': 530,
#          '임효성': 295,
#          '유효성도': 235,
#          '효성빌라의': 566,
#          '효성해링턴플레이스': 782,
#          '효성해링턴코트는': 772,
#          '효성프리미어모터스가': 758,
#          '안정화효성그룹이': 192,
#          '효성여대가': 605,
#          '효성에서': 588,
#          '효성나눔봉사단': 485,
#          '효성기술원을': 476,
#          '전효성이다': 316,
#          '효성가는': 412,
#          '효성전기가': 666,
#          '효성itx사업장': 382,
#          '전효성이라고': 317,
#          '효성웨이': 618,
#          '효성usa의': 397,
#          '유효성분이': 258,
#          '효성증권': 694,
#          '유효성분의': 257,
#          '효성사태': 573,
#          '효성그': 441,
#          '효성중공업은': 690,
#          '효성투자개발이': 747,
#          '효성그룹에서는': 451,
#          '효성해링턴타워': 775,
#          '효성캐피탈의': 719,
#          '효성측은': 705,
#          '개성토건ㆍ미주산업ㆍ효성ㆍ롯데쇼핑': 16,
#          '효성으로부터': 626,
#          '효성캠': 723,
#          '효성그룹과의': 446,
#          '집중효성': 337,
#          '효성가': 411,
#          '효성으로': 625,
#          '실효성에는': 155,
#          '효성등은': 523,
#          '실효성현': 178,
#          '효성오앤비가': 610,
#          '유효성분으로': 252,
#          '효성1호점에서': 369,
#          '효성이란': 635,
#          '유효성분까지': 241,
#          '효성토요타': 735,
#          '효성주': 675,
#          '실효성이나': 165,
#          '안전성ㆍ유효성': 183,
#          '범어효성해링턴플레이스': 102,
#          '범어동효성해링턴플레이스': 100,
#          '효성오앤비와': 614,
#          '효성건설pu는': 419,
#          '효성해링턴코트': 771,
#          '유효성분과': 240,
#          '실효성까지': 140,
#          '효성동에': 518,
#          '효성표': 754,
#          '부사장효성은': 107,
#          '효성해링턴플': 779,
#          '효성웨이는': 619,
#          '효성인포메이션시스템은': 657,
#          '효성시티병원': 579,
#          '청주효성병원은': 343,
#          '효성usa가': 394,
#          '효성처럼': 701,
#          '제공효성은': 325,
#          '효성나눔봉사단장': 495,
#          '효성itx를': 381,
#          '효성ㆍ진흥기업은': 406,
#          '미사역효성해링턴': 84,
#          '전효성과': 305,
#          '발효성분과': 91,
#          '효성짬뽕': 699,
#          '효성ㆍ진흥기업': 405,
#          '유효성분만을': 248,
#          '효성it와': 390,
#          '효성토요타도': 737,
#          '더클래스효성의': 64,
#          '유효성분에': 250,
#          '효성물산의': 537,
#          '기업들효성은': 31,
#          '효성해링턴플레': 780,
#          '효성탄소특화창업보육센터에': 734,
#          '실효성보다는': 148,
#          '특별법은실효성': 350,
#          '유효성분에는': 251,
#          '전복발효성분으로': 303,
#          '실효성부터': 150,
#          '효성사': 568,
#          '원효성': 218,
#          '노틸러스효성에서': 43,
#          '효성베트남': 545,
#          '효성usa는': 395,
#          '효성중에': 692,
#          '효성종합의': 674,
#          '효성탄소특화창업보육센터': 733,
#          '효성캐피탈에': 714,
#          '더클래스효성': 58,
#          '효성itx에': 384,
#          '전효성만의': 308,
#          '효성이엔지는': 637,
#          '강남효성해링턴코트': 12,
#          '효성해링': 766,
#          '슈ㆍ임효성': 125,
#          '유효성분명으로': 249,
#          '현대bf94효성콜': 359,
#          '효성남초ㆍ효성동초ㆍ명현중ㆍ효성고': 505,
#          '효성빌라는': 564,
#          '효성빌라': 562,
#          '효성여대': 604,
#          '발효성분을': 92,
#          '효성엔지니어링': 595,
#          '효성코아': 729,
#          '효성건설은': 423,
#          '효성해링텅': 791,
#          '효성병원을': 552,
#          '효성기술원에서': 474,
#          '효성건설의': 424,
#          '효성동': 515,
#          '효성중공업pg가': 686,
#          '효성윈드파워홀딩스의': 623,
#          '무궁화효성이': 77,
#          '효성1호점에': 368,
#          '효성에도': 587,
#          '효성물산': 532,
#          '효성엔지니어링을': 600,
#          '현대자동차ㆍlgㆍ효성그룹': 361,
#          '효성건설pu': 418,
#          '노틸러스효성': 39,
#          '효성컨테이너의': 728,
#          '효성기술원은': 475,
#          '유효성분은': 255,
#          '효성해링턴플레이': 781,
#          '실효성없는': 152,
#          '효성에서는': 589,
#          '효성원룸': 617,
#          '효성빌라를': 565,
#          '전효성에게': 311,
#          '유효성분들이': 245,
#          '효성캠퍼스': 724,
#          '효성인포메이션시스템': 656,
#          '대상ㆍ효성ㆍ': 54,
#          '효성캐피탈을': 718,
#          '효성전기의': 669,
#          '안전ㆍ유효성': 181,
#          '효성캐피탈은': 717,
#          '효성웨이를': 620,
#          '유효성부터': 237,
#          '김효성': 32,
#          '노틸러스효성의': 46,
#          '효성종합건설은': 672,
#          '효성프리미어모터스는': 759,
#          '더클래스효성과': 59,
#          '효성도요타': 513,
#          'sk네트웍스ㆍ한국타이어ㆍ효성': 3,
#          '효성해링턴플레이스1': 783,
#          '효성나눔봉사단의': 493,
#          '발효성분이': 93,
#          '효성중': 683,
#          '꿈의숲효성해링턴플레이스': 33,
#          '미백유효성분인': 81,
#          '효성itx로': 380,
#          '효성itx노': 376,
#          '실효성ㆍ형평성': 138,
#          '약효성분을': 199,
#          '참여효성': 339,
#          '유효성검사와': 231,
#          '범효성': 103,
#          '효성전기': 665,
#          '효성기술원이라': 479,
#          '효성빌라가': 563,
#          '효성파워택': 749,
#          '효성분이': 560,
#          '효성이엔지': 636,
#          '유효성평가': 276,
#          '유효성에는': 266,
#          '효성인상': 644,
#          '효성직업전문학교': 696,
#          '효성캐피탈이': 720,
#          '평택효성해링턴플레이스': 353,
#          '효성직원이': 698,
#          '효성나눔봉사단은': 490,
#          '청주효성병원과': 342,
#          '효성해링턴스퀘어도': 769,
#          '효성노틸러스의': 508,
#          '약효성분의': 200,
#          '무효성을': 79,
#          '효성나눔봉사단장이': 500,
#          '효성오앤비다': 612,
#          '효성기술': 469,
#          '효성주식을': 677,
#          '효성fms는': 372,
#          '효성주얼리시티': 678,
#          '효성나눔봉사단장을': 499,
#          '효성usa': 393,
#          '효성기술원': 472,
#          '실효성이라고는': 168,
#          '효성나눔봉사단원들은': 486,
#          '효성비자금': 561,
#          '초속효성': 344,
#          '효성굿스프링스는': 436,
#          '전효성스러운': 309,
#          '효성나눔봉사단원이': 489,
#          '효성물산에서': 533,
#          '스효성은': 127,
#          '효성t': 392,
#          '효성인의': 652,
#          '효성엔': 593,
#          '전효성도': 306,
#          '효성어린이공원은': 583,
#          '효성家': 409,
#          '효성토요타로부터': 739,
#          '더프리미엄효성': 66,
#          '효성해링턴스퀘어': 768,
#          '노틸러스효성과': 40,
#          '용산센트럴파크효성해링턴': 211,
#          '효성그룹섬유': 448,
#          '지효성도': 335,
#          '공주신관동효성해링턴플레이스': 24,
#          '효성itx은': 388,
#          '원효성지': 219,
#          '효성과의': 430,
#          '효성그룹주에': 460,
#          '효성종합': 671,
#          '효성기계로': 467,
#          '효성이라는': 634,
#          '효성건설이': 425,
#          '효성nas': 391,
#          '효성사장': 570,
#          '효성1호점': 367,
#          '효성나눔봉사단을': 491,
#          '효성그룹에서': 450,
#          '효성나눔봉사단장인': 502,
#          '선명효성종합은': 118,
#          '효성토요타가': 736,
#          '프리미엄효성에도': 356,
#          '효성백년가약': 543,
#          '유효성분들을': 243,
#          '울산명촌의효성해링턴플레이스가': 217,
#          '효성중공업의': 691,
#          '효성플레이스': 763,
#          '안정성ㆍ유효성을': 190,
#          '유효성ㆍ안전성': 225,
#          '효성건설에서': 422,
#          '틸러스효성': 351,
#          '효성건설': 417,
#          '효성기술원의': 477,
#          '효성에서도': 590,
#          '효성홀딩스': 794,
#          '방송캡쳐임효성은': 95,
#          '효성산업자재pg의': 575,
#          '효성캐피탈과': 711,
#          '남통효성변압기공장에서': 38,
#          '효성그룹주': 458,
#          '사장효성은': 112,
#          '태전효성': 348,
#          '효성투자개발': 742,
#          '임효성과의': 297,
#          '효성그룹으로': 453,
#          '효성엔지니어링은': 599,
#          '전효성에': 310,
#          '효성대로': 509,
#          '효성나눔봉사단을설립': 492,
#          '효성이라': 633,
#          '강남역효성해링턴타워': 10,
#          '비하효성1차아파트': 110,
#          '효성주식': 676,
#          '속효성': 120,
#          '전효성전효성의': 319,
#          '효성계열사': 426,
#          '전효성만을': 307,
#          '행남자기ㆍ효성': 358,
#          '효성토요타로': 738,
#          '효성캐피탈에서': 715,
#          '효성측의': 706,
#          '효성팀은': 748,
#          '효성나눔봉사단원들이': 487,
#          '유효성확인코드인': 282,
#          'exidㆍ전효성ㆍ스누퍼': 0,
#          '유효성에서도': 268,
#          '역효성해링턴타워': 203,
#          '효성병원은': 551,
#          '더클래스효성은': 63,
#          '효성건설도': 421,
#          '임효성씨에': 299,
#          '효성인상은': 645,
#          '효성여고': 602,
#          '효성해링턴플레이스가': 784,
#          '스웨거x전효성': 126,
#          '대효성': 57,
#          '실효성에서': 157,
#          '주장효성은': 329,
#          '노틸러스효성에': 42,
#          '효성왕이': 616,
#          '효성랑카를': 527,
#          '효성아파트와': 582,
#          '실효성ㆍ안전성을': 135,
#          '임효성과': 296,
#          '이효성은': 288,
#          '삼성ㆍ효성ㆍskㆍ한화ㆍlgㆍ한진ㆍcjㆍ한솔ㆍ대림ㆍls그룹': 116,
#          '광명역효성해링턴타워더퍼스트': 27,
#          '발효성': 88,
#          '효성물산으로': 534,
#          '효성웨이와': 621,
#          '효성초': 702,
#          '탄력유효성분을': 347,
#          '후원도효성이': 805,
#          '위례효성해링턴타워': 220,
#          '효성랑카': 524,
#          '효성이나': 631,
#          '실효성있게': 172,
#          '효성도시개발이': 512,
#          '효성기술원과': 473,
#          '효성베트남에': 546,
#          '사전유효성과': 113,
#          '유효성분만': 247,
#          '효성프리미어모터스와': 761,
#          '효성병원과': 549,
#          '효성홀딩스와': 795,
#          '효성캐피': 708,
#          '효성홀딩스의': 796,
#          '효성해링턴타워가': 776,
#          '남통효성변압기공장': 37,
#          '비실효성을': 109,
#          '효성해밀턴': 792,
#          '갓효성': 8,
#          '효성프리미어모터': 756,
#          '효성캐피털': 722,
#          '동물유효성': 70,
#          '유효성분으로서': 253,
#          '실효성마저': 144,
#          '효성굿스프링스': 433,
#          '효성토요타의': 740,
#          '효성인포메이션': 654,
#          '효성등': 522,
#          '효성인포메이션은': 662,
#          '효성굿스프링스가': 434,
#          '효성풍력사업단장을': 755,
#          '효성물산이': 538,
#          '효성해링턴플레이스로': 786,
#          '영양유효성분을': 205,
#          '효성프리미어모터스를': 760,
#          '효성해링턴스퀘어와': 770,
#          '단속실효성을': 48,
#          '더클래스효성이': 65,
#          '제도실효성': 326,
#          '효성베스트빌': 544,
#          '미백유효성분의': 80,
#          '참가효성이': 338,
#          '최효성': 345,
#          '효성오앤비에': 613,
#          '효성그룹을': 455,
#          '독립성ㆍ실효성': 69,
#          '효성흑석마을': 803,
#          '효성굿윌스토어는': 440,
#          '미엄효성': 86,
#          '효성효성이': 802,
#          '미사효성해링턴타워': 85,
#          '효성있는': 664,
#          '유효성의': 272,
#          '효성여고와': 603,
#          '효성오': 608,
#          '실효성보단': 149,
#          '수입효성은': 124,
#          '정책실효성이': 323,
#          '효성타운': 731,
#          '안전성ㆍ유효성을': 186,
#          '안전성ㆍ유효성에': 185,
#          '효성투자개발에': 744,
#          '효성해링턴타워더퍼스트': 777,
#          '발효성분인': 94,
#          '정보누락ㆍ실효성': 321,
#          '효성코아와': 730,
#          '효성ㆍ전북': 402,
#          '효성맨': 531,
#          '효성나눔봉사단이': 494,
#          '효성itx에서는': 385,
#          '효성종합은': 673,
#          '안전성ㆍ유효성이': 187,
#          '효성생활산업': 576,
#          '효성측': 703,
#          '효성동에서': 520,
#          '훈련실효성을': 806,
#          '효성바스프에': 541,
#          '효성나눔봉사단장으로': 497,
#          '시효성을': 129,
#          '효성컨테이': 726,
#          '효성동에는': 519,
#          '약효성분인': 201,
#          '효성해': 765,
#          '효성나눔봉사단장은': 498,
#          '효성기술이': 483,
#          '효성itx사업장을': 383,
#          '풀고유효성이': 354,
#          '효성엔지니어링과': 598,
#          '약용유효성분을': 195,
#          '효성까지': 484,
#          '뜬다효성은': 73,
#          '효성usa법인장도': 396,
#          '효성노틸러스': 507,
#          '강변뉴타운효성해링턴플레이스': 13,
#          '용인보라효성해링턴플레이스': 213,
#          '유효성으로': 269,
#          '안정성ㆍ유효성이': 191,
#          '효성해링턴타워더퍼스트를': 778,
#          '유효성면에서도': 236,
#          '효성동나이': 517,
#          '효성주얼리시티의': 682,
#          '유효성검사를': 230,
#          '용산센트럴파크효성해링턴스퀘어': 212,
#          '효성파워택은': 750,
#          '효성굿스프링스과': 435,
#          '효성인포메이션시스템이다': 661,
#          '핵심유효성분으로': 357,
#          '상도동효성해링턴플레이스': 117,
#          '효성인으로': 647,
#          '효성가톨릭대': 415,
#          '효성기계공업으로': 466,
#          '발효성능과': 89,
#          '강남원효성빌라가': 11,
#          '유효성시험': 263,
#          '효성기': 464,
#          '당부이효성': 49,
#          '유효성평가센터는': 278,
#          '효성바스프': 539,
#          '효성헤링턴플레이스': 793,
#          '실효성마저도': 145,
#          '노틸러스효성을': 45,
#          '정책실효성을': 322,
#          '효성해링턴플레이스의': 789,
#          '영통로효성해링턴플레이스는지하2층': 207,
#          '실효성있나': 174,
#          '효성웨이의': 622,
#          '효성도요타의': 514,
#          '효성로에': 528,
#          '효성바스프와': 542,
#          '효성1구역': 366,
#          '임효성은': 300,
#          '영통로효성해링턴플에이스': 208,
#          '효성홍콩이': 797,
#          '남통효성변압기': 36,
#          '효성그룹주가': 459,
#          '실효성를': 143,
#          '효성회장이': 800,
#          '실효성있는지는': 177,
#          '효성바스프를': 540,
#          '효성나이트는': 504,
#          '더프리미엄효성의': 68,
#          '유력효성이': 222,
#          '실효성있고': 173,
#          '효성인력개발원은': 643,
#          '발효성분': 90,
#          '약효성분': 197,
#          '실효성ㆍ경제성을': 134,
#          '사장이효성': 111,
#          '효성투자개발은': 745,
#          '유효성평가센터': 277,
#          '구로디지털효성해링턴': 28,
#          '스효성이': 128,
#          '난퉁효성변압기공장': 34,
#          '효성회장': 798,
#          '유효성분들의': 244,
#          '효성ㆍ진흥기업이': 407,
#          '효성효': 801,
#          '효성파워택이': 751,
#          '효성굿스프링스와': 437,
#          '효성인으': 646,
#          '효성전기와': 668,
#          '효성그룹과도': 445,
#          '즉효성': 331,
#          '범어효성해링턴': 101,
#          '효성기술연구소를': 470,
#          '효성나이트': 503,
#          '효성부스': 556,
#          '효성캐피탈제십구차': 721,
#          '남통효성': 35,
#          '실효성확보': 179,
#          '제재실효성': 327,
#          '효성랑카가': 525,
#          '유효성분ㆍ제형ㆍ복약': 239,
#          '효성인은': 650,
#          '홍삼유효성분을': 363,
#          '속효성과': 121,
#          '지효성을': 336,
#          '유효성뿐만': 262,
#          '효성굿스프링스와사우디': 438,
#          '배효성의': 98,
#          '효성나눔봉사단장과': 496,
#          '반영효성이': 87,
#          '효성전시관': 670,
#          '대구효성병원과': 51,
#          '대구효성병원장': 53,
#          '변뉴타운효성해링턴플레이스': 104,
#          '유효성뿐': 261,
#          '유효성분추출물': 260,
#          '봉사도효성은': 106,
#          '효성인포메이션시스템의': 659,
#          '효성동굴다리': 516,
#          '효성으로서는': 627,
#          '효성탄소섬유공장': 732,
#          '효성측이': 707,
#          '영통로효성해링턴플레이스': 206,
#          '토요타효성이': 349,
#          '효성엔지니어링이': 601,
#          '유효성검사': 229,
#          '운영효성과': 215,
#          '효성주얼리시티에': 680,
#          '틸러스효성은': 352,
#          '효성기술은': 482,
#          '효성기계': 465,
#          '약효성분도': 198,
#          '인천효성남초': 290,
#          '유효성시험을': 264,
#          '유효성평가센터전임상연구동을': 279,
#          '프리미엄효성': 355,
#          '효성엔지니어링pu': 596,
#          '본사효성캐피탈은': 105,
#          '효성이엔지에': 638,
#          '실효성으로': 159,
#          '효성감리결과': 416,
#          '효성해링턴타우': 774,
#          '효성병원이': 553,
#          '효성여자대학교': 607,
#          '효성사건을': 569,
#          '효성기계와': 468,
#          '효성인들과의': 641,
#          'sk이노베이션ㆍlg화학ㆍ롯데케미칼ㆍ코오롱ㆍ효성ㆍ한화손해보험': 5,
#          '인천효성남초5': 291,
#          '안약유효성분인': 180,
#          '효성만의': 529,
#          '효성해링턴코트의': 773,
#          '회장효성': 365,
#          '대구효성병원': 50,
#          '효성주얼리시티에서': 681,
#          '효성여대생의': 606,
#          '효성해링턴플레이스를': 787,
#          '효성인으로서': 648,
#          '효성컨테이너는': 727,
#          '식물유효성분인': 131,
#          '유효성분들로': 242,
#          '효성그룹판': 461,
#          '효성엑센시티': 592,
#          '효성에는': 586,
#          '실효성보다': 147,
#          '인천효성중': 292,
#          '운효성해링턴플레이스': 216,
#          '안전성유효성': 188,
#          '주효효성이': 330,
#          '후보자이효성': 804,
#          '전효성이에': 318,
#          '실효성에까지': 154,
#          '유효성에서': 267,
#          '유효성분들이나': 246,
#          '효성나눔봉사단장이기도': 501,
#          '자연발효성분은': 301,
#          '실효성ㆍ적합성': 136,
#          '성장효성가': 119,
#          '미백주효성분인': 82,
#          '효성사장에게는': 571,
#          '효성중공업에서': 688,
#          '효성해링턴효성': 790,
#          '실효성있': 171,
#          '면역질환유효성평가센터와': 75,
#          '효성관계자는': 431,
#          '효성고': 427,
#          '효성엔지니어': 594,
#          'hl정의유효성과': 1,
#          '효성그룹株': 443,
#          '약효성': 196,
#          '실현성ㆍ유효성': 132,
#          '효성굿스링스는': 432,
#          '의왕백운밸리효성해링턴플레이스': 285,
#          '강효성': 14,
#          '효성인을': 651,
#          '공청회는실효성': 25,
#          '방송통신위원장이효성': 96,
#          '효성인이': 653,
#          '강남역효성해링턴': 9,
#          '효성스럽고': 578,
#          '효성육교': 624,
#          '유효성ㆍ안전성ㆍ약동학': 226,
#          '효성캐피탈도': 712,
#          '검사실효성': 18,
#          '효성중공업pg장': 687,
#          '공개실효성': 22,
#          '효성쥬얼리시티내': 693,
#          '인수효성그룹이': 289,
#          '안전성ㆍ유효성과': 184,
#          '효성투자개발을': 746,
#          '용인서천효성해링턴플레이스2차': 214,
#          '효성기술원장과': 481,
#          '치료유효성에': 346,
#          '효성그룹회장': 462,
#          '효성하나로': 764,
#          '강효성과': 15,
#          '완효성비료를': 210,
#          '유효성까지': 234,
#          '더클래스효성에': 60,
#          '효성중공업pg': 685,
#          '유효성과의': 233,
#          '효성노인문화센터에서': 506,
#          '고려효성그룹이': 20,
#          '효성엔지니어링pu로': 597,
#          '효성캠퍼스에서': 725,
#          '효성프리미어모터스와의': 762,
#          '효성본사에서': 555,
#          '유효성평가연구단장은': 280,
#          '효성동의': 521,
#          '열기효성이': 204,
#          '부영효성해링턴플레이스': 108,
#          '효성2공장': 370,
#          '효성직원들이': 697,
#          '공덕효성해링턴스퀘어': 23,
#          '화도효성해링턴플레이스': 364,
#          '효성과도': 429,
#          '효성중공업으로': 689,
#          '효성나눔봉사단원은': 488,
#          '효성그룹회장은': 463,
#          '식물유효성분': 130,
#          '효성병원에': 550,
#          '유효성정보가': 275,
#          '효성ㆍ푸르메재단': 408,
#          'sk네트웍스ㆍ한국타이어ㆍ효성ㆍ롯데': 4,
#          '윤효성이': 283,
#          '안정성ㆍ유효성': 189,
#          '실효성이라고': 167,
#          '효성분을': 559,
#          '효성기술연구원은': 471,
#          '더클래스효성와': 62,
#          '대양수력ㆍ효성ㆍ한국전력': 55,
#          '채용효성': 340,
#          '위헌소지ㆍ실효성': 221,
#          '효성인포메이션시스템이': 660,
#          '두산ㆍ효성': 72,
#          '효성캐피탈ㆍ동부메탈': 710,
#          '효성도시개발': 511,
#          '간담회이효성': 7,
#          '효성병원조차': 554,
#          '면해효성그룹': 76,
#          '동효성': 71,
#          '범어동효성': 99,
#          '유효성분으로써': 254,
#          '청주효성병원': 341,
#          '효성사장으로부터': 572,
#          '효성측에서': 704,
#          '효성분': 558,
#          '실효성이없고': 170,
#          '효성건설pu의': 420,
#          '안전성ㆍ안정성ㆍ일관성ㆍ동등성ㆍ유효성이': 182,
#          '효성인포메이션시스템을': 658,
#          '효성itx와의': 387,
#          '장효성': 302,
#          '효성기술원이': 478,
#          '효성ㆍ의왕시': 401,
#          '실효성있는지': 176,
#          '효성itxㆍ서울': 374,
#          '효성투자개발과': 743,
#          '효성굿스핑스': 439,
#          '유효성ㆍ적합성을': 228,
#          '효성ㆍ수출입은행': 399,
#          '대구효성병원은': 52,
#          '효성ㆍ진흥': 404,
#          '배효성': 97,
#          '효성패키징사업부': 752,
#          '무효성': 78,
#          '유지실효성': 223,
#          '점검실효성': 320,
#          '의견실효성': 284,
#          '알고보니효성': 194,
#          '대우건설ㆍ효성': 56,
#          '안효성': 193,
#          '유효성ㆍ안정성': 227,
#          '효성인포메이션이': 663,
#          '삼성ㆍ현대차ㆍskㆍlgㆍ한화ㆍ효성': 115,
#          '과일발효성분으로': 26,
#          '실효성의문': 163,
#          '효성ㆍ삼성전자ㆍ현대자동차': 398,
#          '효성아파트': 581,
#          '효성부회장이': 557,
#          '일관성ㆍ실효성이라는': 293,
#          '미비ㆍ실효성': 83,
#          '효성重': 410,
#          '개소노틸러스효성': 17,
#          '효성투자': 741,
#          '효성ㆍ육군': 400,
#          '곳이다효성': 21,
#          '효성변압기': 547,
#          '지속적ㆍ실효성있는': 333,
#          '효성itx라고': 379,
#          '효성기술원장': 480,
#          '기아차ㆍskㆍ효성ㆍ롯데': 30,
#          'skㆍ효성': 2,
#          '일산효성요양병원': 294,
#          '이효성에': 287,
#          '송효성': 123,
#          '효성ㆍ전북도': 403,
#          '효성인포메이션시': 655,
#          '효성가도': 413,
#          '효성서': 577,
#          '효성이지난': 639,
#          '효성아이티엑스': 580,
#          '맞대이효성': 74,
#          '노틸러스효성과의': 41,
#          '효성평가지수들이': 753,
#          '손효성': 122,
#          '삼성sdiㆍ효성': 114,
#          '효성뿐만': 567,
#          '유효성평가지수들이': 281,
#          '효성주얼리시티는': 679,
#          '실효성논란': 141,
#          'ㆍ이효성': 6,
#          '실효성ㆍ현실성': 137,
#          '효성3세': 371,
#          '검찰ㆍ효성': 19,
#          '현대차ㆍgsㆍ효성': 362,
#          '효성산업': 574,
#          '현대백화점ㆍ한진ㆍ효성': 360})

# %%
list(test_dict.items())
# Out:
# [('실효성에도', 156),
#  ('실효성은', 160),
#  ('실효성이', 164),
#  ('효성의', 629),
#  ('효성이다', 632),
#  ('전효성이', 315),
#  ('실효성', 133),
#  ('효성을', 628),
#  ('효성이', 630),
#  ('효성itx는', 377),
#  ('실효성에', 153),
#  ('효성도', 510),
#  ('효성그룹이', 457),
#  ('유효성이', 273),
#  ('지효성', 334),
#  ('실효성이다', 166),
#  ('실효성을', 161),
#  ('노틸러스효성이', 47),
#  ('유효성은', 270),
#  ('실효성및', 146),
#  ('약효성을', 202),
#  ('유효성에', 265),
#  ('효성그룹', 442),
#  ('유효성을', 271),
#  ('실효성도', 142),
#  ('효성해링턴', 767),
#  ('더클래스효성에서는', 61),
#  ('효성그룹의', 456),
#  ('효성중공업', 684),
#  ('효성물산을', 536),
#  ('효성에', 584),
#  ('효성그룹은', 454),
#  ('효성병원', 548),
#  ('규제실효성', 29),
#  ('효성오앤비', 609),
#  ('효성증권이', 695),
#  ('유효성분', 238),
#  ('유효성이나', 274),
#  ('이효성', 286),
#  ('전효성은', 312),
#  ('전효성을', 313),
#  ('효성과', 428),
#  ('효성캐피탈에서는', 716),
#  ('전효성의', 314),
#  ('효성그룹에', 449),
#  ('실효성과', 139),
#  ('효성itx와', 386),
#  ('효성가의', 414),
#  ('효성itx', 373),
#  ('실효성엔', 158),
#  ('효성itx가', 375),
#  ('효성에서만', 591),
#  ('효성프리미어모터스', 757),
#  ('실효성의', 162),
#  ('유효성분인', 259),
#  ('효성그룹과', 444),
#  ('효성캐피탈', 709),
#  ('효성인', 640),
#  ('실효성뿐', 151),
#  ('실효성이라는', 169),
#  ('오토밸리로효성해링턴플레이스', 209),
#  ('유효성', 224),
#  ('실효성있는', 175),
#  ('효성캐피탈로부터', 713),
#  ('효성창조경제펀드에서', 700),
#  ('효성오앤비는', 611),
#  ('유효성분을', 256),
#  ('효성에게', 585),
#  ('효성itx의', 389),
#  ('즉효성과', 332),
#  ('전효성', 304),
#  ('효성인으로서의', 649),
#  ('효성전기는', 667),
#  ('임효성씨는', 298),
#  ('효성회장을', 799),
#  ('효성랑카공장에서', 526),
#  ('유효성과', 232),
#  ('더프리미엄효성은', 67),
#  ('효성물산은', 535),
#  ('효성itx도', 378),
#  ('정효성', 324),
#  ('효성인력개발원', 642),
#  ('조효성', 328),
#  ('효성오앤비의', 615),
#  ('노틸러스효성은', 44),
#  ('효성해링턴플레이스는', 785),
#  ('효성그룹도', 447),
#  ('효성해링턴플레이스와', 788),
#  ('효성그룹엔', 452),
#  ('효성만이', 530),
#  ('임효성', 295),
#  ('유효성도', 235),
#  ('효성빌라의', 566),
#  ('효성해링턴플레이스', 782),
#  ('효성해링턴코트는', 772),
#  ('효성프리미어모터스가', 758),
#  ('안정화효성그룹이', 192),
#  ('효성여대가', 605),
#  ('효성에서', 588),
#  ('효성나눔봉사단', 485),
#  ('효성기술원을', 476),
#  ('전효성이다', 316),
#  ('효성가는', 412),
#  ('효성전기가', 666),
#  ('효성itx사업장', 382),
#  ('전효성이라고', 317),
#  ('효성웨이', 618),
#  ('효성usa의', 397),
#  ('유효성분이', 258),
#  ('효성증권', 694),
#  ('유효성분의', 257),
#  ('효성사태', 573),
#  ('효성그', 441),
#  ('효성중공업은', 690),
#  ('효성투자개발이', 747),
#  ('효성그룹에서는', 451),
#  ('효성해링턴타워', 775),
#  ('효성캐피탈의', 719),
#  ('효성측은', 705),
#  ('개성토건ㆍ미주산업ㆍ효성ㆍ롯데쇼핑', 16),
#  ('효성으로부터', 626),
#  ('효성캠', 723),
#  ('효성그룹과의', 446),
#  ('집중효성', 337),
#  ('효성가', 411),
#  ('효성으로', 625),
#  ('실효성에는', 155),
#  ('효성등은', 523),
#  ('실효성현', 178),
#  ('효성오앤비가', 610),
#  ('유효성분으로', 252),
#  ('효성1호점에서', 369),
#  ('효성이란', 635),
#  ('유효성분까지', 241),
#  ('효성토요타', 735),
#  ('효성주', 675),
#  ('실효성이나', 165),
#  ('안전성ㆍ유효성', 183),
#  ('범어효성해링턴플레이스', 102),
#  ('범어동효성해링턴플레이스', 100),
#  ('효성오앤비와', 614),
#  ('효성건설pu는', 419),
#  ('효성해링턴코트', 771),
#  ('유효성분과', 240),
#  ('실효성까지', 140),
#  ('효성동에', 518),
#  ('효성표', 754),
#  ('부사장효성은', 107),
#  ('효성해링턴플', 779),
#  ('효성웨이는', 619),
#  ('효성인포메이션시스템은', 657),
#  ('효성시티병원', 579),
#  ('청주효성병원은', 343),
#  ('효성usa가', 394),
#  ('효성처럼', 701),
#  ('제공효성은', 325),
#  ('효성나눔봉사단장', 495),
#  ('효성itx를', 381),
#  ('효성ㆍ진흥기업은', 406),
#  ('미사역효성해링턴', 84),
#  ('전효성과', 305),
#  ('발효성분과', 91),
#  ('효성짬뽕', 699),
#  ('효성ㆍ진흥기업', 405),
#  ('유효성분만을', 248),
#  ('효성it와', 390),
#  ('효성토요타도', 737),
#  ('더클래스효성의', 64),
#  ('유효성분에', 250),
#  ('효성물산의', 537),
#  ('기업들효성은', 31),
#  ('효성해링턴플레', 780),
#  ('효성탄소특화창업보육센터에', 734),
#  ('실효성보다는', 148),
#  ('특별법은실효성', 350),
#  ('유효성분에는', 251),
#  ('전복발효성분으로', 303),
#  ('실효성부터', 150),
#  ('효성사', 568),
#  ('원효성', 218),
#  ('노틸러스효성에서', 43),
#  ('효성베트남', 545),
#  ('효성usa는', 395),
#  ('효성중에', 692),
#  ('효성종합의', 674),
#  ('효성탄소특화창업보육센터', 733),
#  ('효성캐피탈에', 714),
#  ('더클래스효성', 58),
#  ('효성itx에', 384),
#  ('전효성만의', 308),
#  ('효성이엔지는', 637),
#  ('강남효성해링턴코트', 12),
#  ('효성해링', 766),
#  ('슈ㆍ임효성', 125),
#  ('유효성분명으로', 249),
#  ('현대bf94효성콜', 359),
#  ('효성남초ㆍ효성동초ㆍ명현중ㆍ효성고', 505),
#  ('효성빌라는', 564),
#  ('효성빌라', 562),
#  ('효성여대', 604),
#  ('발효성분을', 92),
#  ('효성엔지니어링', 595),
#  ('효성코아', 729),
#  ('효성건설은', 423),
#  ('효성해링텅', 791),
#  ('효성병원을', 552),
#  ('효성기술원에서', 474),
#  ('효성건설의', 424),
#  ('효성동', 515),
#  ('효성중공업pg가', 686),
#  ('효성윈드파워홀딩스의', 623),
#  ('무궁화효성이', 77),
#  ('효성1호점에', 368),
#  ('효성에도', 587),
#  ('효성물산', 532),
#  ('효성엔지니어링을', 600),
#  ('현대자동차ㆍlgㆍ효성그룹', 361),
#  ('효성건설pu', 418),
#  ('노틸러스효성', 39),
#  ('효성컨테이너의', 728),
#  ('효성기술원은', 475),
#  ('유효성분은', 255),
#  ('효성해링턴플레이', 781),
#  ('실효성없는', 152),
#  ('효성에서는', 589),
#  ('효성원룸', 617),
#  ('효성빌라를', 565),
#  ('전효성에게', 311),
#  ('유효성분들이', 245),
#  ('효성캠퍼스', 724),
#  ('효성인포메이션시스템', 656),
#  ('대상ㆍ효성ㆍ', 54),
#  ('효성캐피탈을', 718),
#  ('효성전기의', 669),
#  ('안전ㆍ유효성', 181),
#  ('효성캐피탈은', 717),
#  ('효성웨이를', 620),
#  ('유효성부터', 237),
#  ('김효성', 32),
#  ('노틸러스효성의', 46),
#  ('효성종합건설은', 672),
#  ('효성프리미어모터스는', 759),
#  ('더클래스효성과', 59),
#  ('효성도요타', 513),
#  ('sk네트웍스ㆍ한국타이어ㆍ효성', 3),
#  ('효성해링턴플레이스1', 783),
#  ('효성나눔봉사단의', 493),
#  ('발효성분이', 93),
#  ('효성중', 683),
#  ('꿈의숲효성해링턴플레이스', 33),
#  ('미백유효성분인', 81),
#  ('효성itx로', 380),
#  ('효성itx노', 376),
#  ('실효성ㆍ형평성', 138),
#  ('약효성분을', 199),
#  ('참여효성', 339),
#  ('유효성검사와', 231),
#  ('범효성', 103),
#  ('효성전기', 665),
#  ('효성기술원이라', 479),
#  ('효성빌라가', 563),
#  ('효성파워택', 749),
#  ('효성분이', 560),
#  ('효성이엔지', 636),
#  ('유효성평가', 276),
#  ('유효성에는', 266),
#  ('효성인상', 644),
#  ('효성직업전문학교', 696),
#  ('효성캐피탈이', 720),
#  ('평택효성해링턴플레이스', 353),
#  ('효성직원이', 698),
#  ('효성나눔봉사단은', 490),
#  ('청주효성병원과', 342),
#  ('효성해링턴스퀘어도', 769),
#  ('효성노틸러스의', 508),
#  ('약효성분의', 200),
#  ('무효성을', 79),
#  ('효성나눔봉사단장이', 500),
#  ('효성오앤비다', 612),
#  ('효성기술', 469),
#  ('효성주식을', 677),
#  ('효성fms는', 372),
#  ('효성주얼리시티', 678),
#  ('효성나눔봉사단장을', 499),
#  ('효성usa', 393),
#  ('효성기술원', 472),
#  ('실효성이라고는', 168),
#  ('효성나눔봉사단원들은', 486),
#  ('효성비자금', 561),
#  ('초속효성', 344),
#  ('효성굿스프링스는', 436),
#  ('전효성스러운', 309),
#  ('효성나눔봉사단원이', 489),
#  ('효성물산에서', 533),
#  ('스효성은', 127),
#  ('효성t', 392),
#  ('효성인의', 652),
#  ('효성엔', 593),
#  ('전효성도', 306),
#  ('효성어린이공원은', 583),
#  ('효성家', 409),
#  ('효성토요타로부터', 739),
#  ('더프리미엄효성', 66),
#  ('효성해링턴스퀘어', 768),
#  ('노틸러스효성과', 40),
#  ('용산센트럴파크효성해링턴', 211),
#  ('효성그룹섬유', 448),
#  ('지효성도', 335),
#  ('공주신관동효성해링턴플레이스', 24),
#  ('효성itx은', 388),
#  ('원효성지', 219),
#  ('효성과의', 430),
#  ('효성그룹주에', 460),
#  ('효성종합', 671),
#  ('효성기계로', 467),
#  ('효성이라는', 634),
#  ('효성건설이', 425),
#  ('효성nas', 391),
#  ('효성사장', 570),
#  ('효성1호점', 367),
#  ('효성나눔봉사단을', 491),
#  ('효성그룹에서', 450),
#  ('효성나눔봉사단장인', 502),
#  ('선명효성종합은', 118),
#  ('효성토요타가', 736),
#  ('프리미엄효성에도', 356),
#  ('효성백년가약', 543),
#  ('유효성분들을', 243),
#  ('울산명촌의효성해링턴플레이스가', 217),
#  ('효성중공업의', 691),
#  ('효성플레이스', 763),
#  ('안정성ㆍ유효성을', 190),
#  ('유효성ㆍ안전성', 225),
#  ('효성건설에서', 422),
#  ('틸러스효성', 351),
#  ('효성건설', 417),
#  ('효성기술원의', 477),
#  ('효성에서도', 590),
#  ('효성홀딩스', 794),
#  ('방송캡쳐임효성은', 95),
#  ('효성산업자재pg의', 575),
#  ('효성캐피탈과', 711),
#  ('남통효성변압기공장에서', 38),
#  ('효성그룹주', 458),
#  ('사장효성은', 112),
#  ('태전효성', 348),
#  ('효성투자개발', 742),
#  ('임효성과의', 297),
#  ('효성그룹으로', 453),
#  ('효성엔지니어링은', 599),
#  ('전효성에', 310),
#  ('효성대로', 509),
#  ('효성나눔봉사단을설립', 492),
#  ('효성이라', 633),
#  ('강남역효성해링턴타워', 10),
#  ('비하효성1차아파트', 110),
#  ('효성주식', 676),
#  ('속효성', 120),
#  ('전효성전효성의', 319),
#  ('효성계열사', 426),
#  ('전효성만을', 307),
#  ('행남자기ㆍ효성', 358),
#  ('효성토요타로', 738),
#  ('효성캐피탈에서', 715),
#  ('효성측의', 706),
#  ('효성팀은', 748),
#  ('효성나눔봉사단원들이', 487),
#  ('유효성확인코드인', 282),
#  ('exidㆍ전효성ㆍ스누퍼', 0),
#  ('유효성에서도', 268),
#  ('역효성해링턴타워', 203),
#  ('효성병원은', 551),
#  ('더클래스효성은', 63),
#  ('효성건설도', 421),
#  ('임효성씨에', 299),
#  ('효성인상은', 645),
#  ('효성여고', 602),
#  ('효성해링턴플레이스가', 784),
#  ('스웨거x전효성', 126),
#  ('대효성', 57),
#  ('실효성에서', 157),
#  ('주장효성은', 329),
#  ('노틸러스효성에', 42),
#  ('효성왕이', 616),
#  ('효성랑카를', 527),
#  ('효성아파트와', 582),
#  ('실효성ㆍ안전성을', 135),
#  ('임효성과', 296),
#  ('이효성은', 288),
#  ('삼성ㆍ효성ㆍskㆍ한화ㆍlgㆍ한진ㆍcjㆍ한솔ㆍ대림ㆍls그룹', 116),
#  ('광명역효성해링턴타워더퍼스트', 27),
#  ('발효성', 88),
#  ('효성물산으로', 534),
#  ('효성웨이와', 621),
#  ('효성초', 702),
#  ('탄력유효성분을', 347),
#  ('후원도효성이', 805),
#  ('위례효성해링턴타워', 220),
#  ('효성랑카', 524),
#  ('효성이나', 631),
#  ('실효성있게', 172),
#  ('효성도시개발이', 512),
#  ('효성기술원과', 473),
#  ('효성베트남에', 546),
#  ('사전유효성과', 113),
#  ('유효성분만', 247),
#  ('효성프리미어모터스와', 761),
#  ('효성병원과', 549),
#  ('효성홀딩스와', 795),
#  ('효성캐피', 708),
#  ('효성홀딩스의', 796),
#  ('효성해링턴타워가', 776),
#  ('남통효성변압기공장', 37),
#  ('비실효성을', 109),
#  ('효성해밀턴', 792),
#  ('갓효성', 8),
#  ('효성프리미어모터', 756),
#  ('효성캐피털', 722),
#  ('동물유효성', 70),
#  ('유효성분으로서', 253),
#  ('실효성마저', 144),
#  ('효성굿스프링스', 433),
#  ('효성토요타의', 740),
#  ('효성인포메이션', 654),
#  ('효성등', 522),
#  ('효성인포메이션은', 662),
#  ('효성굿스프링스가', 434),
#  ('효성풍력사업단장을', 755),
#  ('효성물산이', 538),
#  ('효성해링턴플레이스로', 786),
#  ('영양유효성분을', 205),
#  ('효성프리미어모터스를', 760),
#  ('효성해링턴스퀘어와', 770),
#  ('단속실효성을', 48),
#  ('더클래스효성이', 65),
#  ('제도실효성', 326),
#  ('효성베스트빌', 544),
#  ('미백유효성분의', 80),
#  ('참가효성이', 338),
#  ('최효성', 345),
#  ('효성오앤비에', 613),
#  ('효성그룹을', 455),
#  ('독립성ㆍ실효성', 69),
#  ('효성흑석마을', 803),
#  ('효성굿윌스토어는', 440),
#  ('미엄효성', 86),
#  ('효성효성이', 802),
#  ('미사효성해링턴타워', 85),
#  ('효성있는', 664),
#  ('유효성의', 272),
#  ('효성여고와', 603),
#  ('효성오', 608),
#  ('실효성보단', 149),
#  ('수입효성은', 124),
#  ('정책실효성이', 323),
#  ('효성타운', 731),
#  ('안전성ㆍ유효성을', 186),
#  ('안전성ㆍ유효성에', 185),
#  ('효성투자개발에', 744),
#  ('효성해링턴타워더퍼스트', 777),
#  ('발효성분인', 94),
#  ('정보누락ㆍ실효성', 321),
#  ('효성코아와', 730),
#  ('효성ㆍ전북', 402),
#  ('효성맨', 531),
#  ('효성나눔봉사단이', 494),
#  ('효성itx에서는', 385),
#  ('효성종합은', 673),
#  ('안전성ㆍ유효성이', 187),
#  ('효성생활산업', 576),
#  ('효성측', 703),
#  ('효성동에서', 520),
#  ('훈련실효성을', 806),
#  ('효성바스프에', 541),
#  ('효성나눔봉사단장으로', 497),
#  ('시효성을', 129),
#  ('효성컨테이', 726),
#  ('효성동에는', 519),
#  ('약효성분인', 201),
#  ('효성해', 765),
#  ('효성나눔봉사단장은', 498),
#  ('효성기술이', 483),
#  ('효성itx사업장을', 383),
#  ('풀고유효성이', 354),
#  ('효성엔지니어링과', 598),
#  ('약용유효성분을', 195),
#  ('효성까지', 484),
#  ('뜬다효성은', 73),
#  ('효성usa법인장도', 396),
#  ('효성노틸러스', 507),
#  ('강변뉴타운효성해링턴플레이스', 13),
#  ('용인보라효성해링턴플레이스', 213),
#  ('유효성으로', 269),
#  ('안정성ㆍ유효성이', 191),
#  ('효성해링턴타워더퍼스트를', 778),
#  ('유효성면에서도', 236),
#  ('효성동나이', 517),
#  ('효성주얼리시티의', 682),
#  ('유효성검사를', 230),
#  ('용산센트럴파크효성해링턴스퀘어', 212),
#  ('효성파워택은', 750),
#  ('효성굿스프링스과', 435),
#  ('효성인포메이션시스템이다', 661),
#  ('핵심유효성분으로', 357),
#  ('상도동효성해링턴플레이스', 117),
#  ('효성인으로', 647),
#  ('효성가톨릭대', 415),
#  ('효성기계공업으로', 466),
#  ('발효성능과', 89),
#  ('강남원효성빌라가', 11),
#  ('유효성시험', 263),
#  ('효성기', 464),
#  ('당부이효성', 49),
#  ('유효성평가센터는', 278),
#  ('효성바스프', 539),
#  ('효성헤링턴플레이스', 793),
#  ('실효성마저도', 145),
#  ('노틸러스효성을', 45),
#  ('정책실효성을', 322),
#  ('효성해링턴플레이스의', 789),
#  ('영통로효성해링턴플레이스는지하2층', 207),
#  ('실효성있나', 174),
#  ('효성웨이의', 622),
#  ('효성도요타의', 514),
#  ('효성로에', 528),
#  ('효성바스프와', 542),
#  ('효성1구역', 366),
#  ('임효성은', 300),
#  ('영통로효성해링턴플에이스', 208),
#  ('효성홍콩이', 797),
#  ('남통효성변압기', 36),
#  ('효성그룹주가', 459),
#  ('실효성를', 143),
#  ('효성회장이', 800),
#  ('실효성있는지는', 177),
#  ('효성바스프를', 540),
#  ('효성나이트는', 504),
#  ('더프리미엄효성의', 68),
#  ('유력효성이', 222),
#  ('실효성있고', 173),
#  ('효성인력개발원은', 643),
#  ('발효성분', 90),
#  ('약효성분', 197),
#  ('실효성ㆍ경제성을', 134),
#  ('사장이효성', 111),
#  ('효성투자개발은', 745),
#  ('유효성평가센터', 277),
#  ('구로디지털효성해링턴', 28),
#  ('스효성이', 128),
#  ('난퉁효성변압기공장', 34),
#  ('효성회장', 798),
#  ('유효성분들의', 244),
#  ('효성ㆍ진흥기업이', 407),
#  ('효성효', 801),
#  ('효성파워택이', 751),
#  ('효성굿스프링스와', 437),
#  ('효성인으', 646),
#  ('효성전기와', 668),
#  ('효성그룹과도', 445),
#  ('즉효성', 331),
#  ('범어효성해링턴', 101),
#  ('효성기술연구소를', 470),
#  ('효성나이트', 503),
#  ('효성부스', 556),
#  ('효성캐피탈제십구차', 721),
#  ('남통효성', 35),
#  ('실효성확보', 179),
#  ('제재실효성', 327),
#  ('효성랑카가', 525),
#  ('유효성분ㆍ제형ㆍ복약', 239),
#  ('효성인은', 650),
#  ('홍삼유효성분을', 363),
#  ('속효성과', 121),
#  ('지효성을', 336),
#  ('유효성뿐만', 262),
#  ('효성굿스프링스와사우디', 438),
#  ('배효성의', 98),
#  ('효성나눔봉사단장과', 496),
#  ('반영효성이', 87),
#  ('효성전시관', 670),
#  ('대구효성병원과', 51),
#  ('대구효성병원장', 53),
#  ('변뉴타운효성해링턴플레이스', 104),
#  ('유효성뿐', 261),
#  ('유효성분추출물', 260),
#  ('봉사도효성은', 106),
#  ('효성인포메이션시스템의', 659),
#  ('효성동굴다리', 516),
#  ('효성으로서는', 627),
#  ('효성탄소섬유공장', 732),
#  ('효성측이', 707),
#  ('영통로효성해링턴플레이스', 206),
#  ('토요타효성이', 349),
#  ('효성엔지니어링이', 601),
#  ('유효성검사', 229),
#  ('운영효성과', 215),
#  ('효성주얼리시티에', 680),
#  ('틸러스효성은', 352),
#  ('효성기술은', 482),
#  ('효성기계', 465),
#  ('약효성분도', 198),
#  ('인천효성남초', 290),
#  ('유효성시험을', 264),
#  ('유효성평가센터전임상연구동을', 279),
#  ('프리미엄효성', 355),
#  ('효성엔지니어링pu', 596),
#  ('본사효성캐피탈은', 105),
#  ('효성이엔지에', 638),
#  ('실효성으로', 159),
#  ('효성감리결과', 416),
#  ('효성해링턴타우', 774),
#  ('효성병원이', 553),
#  ('효성여자대학교', 607),
#  ('효성사건을', 569),
#  ('효성기계와', 468),
#  ('효성인들과의', 641),
#  ('sk이노베이션ㆍlg화학ㆍ롯데케미칼ㆍ코오롱ㆍ효성ㆍ한화손해보험', 5),
#  ('인천효성남초5', 291),
#  ('안약유효성분인', 180),
#  ('효성만의', 529),
#  ('효성해링턴코트의', 773),
#  ('회장효성', 365),
#  ('대구효성병원', 50),
#  ('효성주얼리시티에서', 681),
#  ('효성여대생의', 606),
#  ('효성해링턴플레이스를', 787),
#  ('효성인으로서', 648),
#  ('효성컨테이너는', 727),
#  ('식물유효성분인', 131),
#  ('유효성분들로', 242),
#  ('효성그룹판', 461),
#  ('효성엑센시티', 592),
#  ('효성에는', 586),
#  ('실효성보다', 147),
#  ('인천효성중', 292),
#  ('운효성해링턴플레이스', 216),
#  ('안전성유효성', 188),
#  ('주효효성이', 330),
#  ('후보자이효성', 804),
#  ('전효성이에', 318),
#  ('실효성에까지', 154),
#  ('유효성에서', 267),
#  ('유효성분들이나', 246),
#  ('효성나눔봉사단장이기도', 501),
#  ('자연발효성분은', 301),
#  ('실효성ㆍ적합성', 136),
#  ('성장효성가', 119),
#  ('미백주효성분인', 82),
#  ('효성사장에게는', 571),
#  ('효성중공업에서', 688),
#  ('효성해링턴효성', 790),
#  ('실효성있', 171),
#  ('면역질환유효성평가센터와', 75),
#  ('효성관계자는', 431),
#  ('효성고', 427),
#  ('효성엔지니어', 594),
#  ('hl정의유효성과', 1),
#  ('효성그룹株', 443),
#  ('약효성', 196),
#  ('실현성ㆍ유효성', 132),
#  ('효성굿스링스는', 432),
#  ('의왕백운밸리효성해링턴플레이스', 285),
#  ('강효성', 14),
#  ('효성인을', 651),
#  ('공청회는실효성', 25),
#  ('방송통신위원장이효성', 96),
#  ('효성인이', 653),
#  ('강남역효성해링턴', 9),
#  ('효성스럽고', 578),
#  ('효성육교', 624),
#  ('유효성ㆍ안전성ㆍ약동학', 226),
#  ('효성캐피탈도', 712),
#  ('검사실효성', 18),
#  ('효성중공업pg장', 687),
#  ('공개실효성', 22),
#  ('효성쥬얼리시티내', 693),
#  ('인수효성그룹이', 289),
#  ('안전성ㆍ유효성과', 184),
#  ('효성투자개발을', 746),
#  ('용인서천효성해링턴플레이스2차', 214),
#  ('효성기술원장과', 481),
#  ('치료유효성에', 346),
#  ('효성그룹회장', 462),
#  ('효성하나로', 764),
#  ('강효성과', 15),
#  ('완효성비료를', 210),
#  ('유효성까지', 234),
#  ('더클래스효성에', 60),
#  ('효성중공업pg', 685),
#  ('유효성과의', 233),
#  ('효성노인문화센터에서', 506),
#  ('고려효성그룹이', 20),
#  ('효성엔지니어링pu로', 597),
#  ('효성캠퍼스에서', 725),
#  ('효성프리미어모터스와의', 762),
#  ('효성본사에서', 555),
#  ('유효성평가연구단장은', 280),
#  ('효성동의', 521),
#  ('열기효성이', 204),
#  ('부영효성해링턴플레이스', 108),
#  ('효성2공장', 370),
#  ('효성직원들이', 697),
#  ('공덕효성해링턴스퀘어', 23),
#  ('화도효성해링턴플레이스', 364),
#  ('효성과도', 429),
#  ('효성중공업으로', 689),
#  ('효성나눔봉사단원은', 488),
#  ('효성그룹회장은', 463),
#  ('식물유효성분', 130),
#  ('효성병원에', 550),
#  ('유효성정보가', 275),
#  ('효성ㆍ푸르메재단', 408),
#  ('sk네트웍스ㆍ한국타이어ㆍ효성ㆍ롯데', 4),
#  ('윤효성이', 283),
#  ('안정성ㆍ유효성', 189),
#  ('실효성이라고', 167),
#  ('효성분을', 559),
#  ('효성기술연구원은', 471),
#  ('더클래스효성와', 62),
#  ('대양수력ㆍ효성ㆍ한국전력', 55),
#  ('채용효성', 340),
#  ('위헌소지ㆍ실효성', 221),
#  ('효성인포메이션시스템이', 660),
#  ('두산ㆍ효성', 72),
#  ('효성캐피탈ㆍ동부메탈', 710),
#  ('효성도시개발', 511),
#  ('간담회이효성', 7),
#  ('효성병원조차', 554),
#  ('면해효성그룹', 76),
#  ('동효성', 71),
#  ('범어동효성', 99),
#  ('유효성분으로써', 254),
#  ('청주효성병원', 341),
#  ('효성사장으로부터', 572),
#  ('효성측에서', 704),
#  ('효성분', 558),
#  ('실효성이없고', 170),
#  ('효성건설pu의', 420),
#  ('안전성ㆍ안정성ㆍ일관성ㆍ동등성ㆍ유효성이', 182),
#  ('효성인포메이션시스템을', 658),
#  ('효성itx와의', 387),
#  ('장효성', 302),
#  ('효성기술원이', 478),
#  ('효성ㆍ의왕시', 401),
#  ('실효성있는지', 176),
#  ('효성itxㆍ서울', 374),
#  ('효성투자개발과', 743),
#  ('효성굿스핑스', 439),
#  ('유효성ㆍ적합성을', 228),
#  ('효성ㆍ수출입은행', 399),
#  ('대구효성병원은', 52),
#  ('효성ㆍ진흥', 404),
#  ('배효성', 97),
#  ('효성패키징사업부', 752),
#  ('무효성', 78),
#  ('유지실효성', 223),
#  ('점검실효성', 320),
#  ('의견실효성', 284),
#  ('알고보니효성', 194),
#  ('대우건설ㆍ효성', 56),
#  ('안효성', 193),
#  ('유효성ㆍ안정성', 227),
#  ('효성인포메이션이', 663),
#  ('삼성ㆍ현대차ㆍskㆍlgㆍ한화ㆍ효성', 115),
#  ('과일발효성분으로', 26),
#  ('실효성의문', 163),
#  ('효성ㆍ삼성전자ㆍ현대자동차', 398),
#  ('효성아파트', 581),
#  ('효성부회장이', 557),
#  ('일관성ㆍ실효성이라는', 293),
#  ('미비ㆍ실효성', 83),
#  ('효성重', 410),
#  ('개소노틸러스효성', 17),
#  ('효성투자', 741),
#  ('효성ㆍ육군', 400),
#  ('곳이다효성', 21),
#  ('효성변압기', 547),
#  ('지속적ㆍ실효성있는', 333),
#  ('효성itx라고', 379),
#  ('효성기술원장', 480),
#  ('기아차ㆍskㆍ효성ㆍ롯데', 30),
#  ('skㆍ효성', 2),
#  ('일산효성요양병원', 294),
#  ('이효성에', 287),
#  ('송효성', 123),
#  ('효성ㆍ전북도', 403),
#  ('효성인포메이션시', 655),
#  ('효성가도', 413),
#  ('효성서', 577),
#  ('효성이지난', 639),
#  ('효성아이티엑스', 580),
#  ('맞대이효성', 74),
#  ('노틸러스효성과의', 41),
#  ('효성평가지수들이', 753),
#  ('손효성', 122),
#  ('삼성sdiㆍ효성', 114),
#  ('효성뿐만', 567),
#  ('유효성평가지수들이', 281),
#  ('효성주얼리시티는', 679),
#  ('실효성논란', 141),
#  ('ㆍ이효성', 6),
#  ('실효성ㆍ현실성', 137),
#  ('효성3세', 371),
#  ('검찰ㆍ효성', 19),
#  ('현대차ㆍgsㆍ효성', 362),
#  ('효성산업', 574),
#  ('현대백화점ㆍ한진ㆍ효성', 360)]

# %%
freqs = [(word, matrix.getcol(idx).sum()) for word, idx in vect.vocabulary_.items()]

# %%
for phrase, times in sorted(freqs, key=lambda x: -x[1])[:150]:
    if phrase not in related_company:
        print(phrase, times)
# Out:
# 효성은 3237
# 실효성 2919
# 실효성을 1969
# 실효성이 1919
# 효성이 1329
# 효성의 1037
# 효성해링턴 755
# 실효성에 739
# 유효성 609
# 효성그룹 562
# 유효성을 561
# 이효성 487
# 효성과 359
# 유효성과 283
# 효성itx는 232
# 효성에 224
# 유효성이 187
# 실효성은 177
# 유효성분을 176
# 전효성 160
# 실효성과 159
# 효성을 132
# 전효성은 123
# 효성그룹은 116
# 실효성도 115
# 유효성분 105
# 효성그룹이 104
# 유효성분이 94
# 유효성분으로 91
# 효성그룹의 88
# 유효성에 85
# 노틸러스효성 78
# 실효성있는 75
# 효성해링턴플레이스 72
# 전효성이 71
# 효성나눔봉사단장 70
# 효성itx가 66
# 효성가 62
# 노틸러스효성은 59
# 유효성분의 56
# 정효성 44
# 전효성의 43
# 효성오앤비 42
# 효성itx와 38
# 효성해링턴타워 37
# 효성도 36
# 유효성분인 36
# 효성캐피탈은 35
# 노틸러스효성이 32
# 효성그룹에 30
# 안전성ㆍ유효성 29
# 효성나눔봉사단은 29
# 효성itx의 27
# 임효성 27
# 효성오앤비는 25
# 김효성 25
# 유효성평가 25
# 실효성에는 22
# 실효성의 21
# 효성그룹과 21
# 효성으로부터 20
# 효성병원 19
# 효성전기 19
# 유효성은 18
# 효성으로 18
# 효성에서 17
# 효성빌라 16
# 실효성에도 15
# 효성그룹도 15
# 효성나눔봉사단 15
# 효성usa 15
# 효성나눔봉사단장은 15
# 효성물산을 14
# 효성1호점 14
# 실효성있게 14
# 효성웨이 13
# 전효성과 13
# 효성usa는 13
# 효성엔지니어링 13
# 효성물산 13
# 실효성엔 12
# 유효성도 12
# 유효성분과 12
# 유효성분들을 12
# 효성오앤비의 11
# 효성해링턴코트 11
# 노틸러스효성의 11
# 효성해링턴플레이스는 10
# 효성투자개발이 10
# 효성캐피탈의 10
# 효성동 10
# 효성도요타 10
# 효성기술 10
# 효성나눔봉사단이 10
# 효성측은 9
# 미사역효성해링턴 9
# 유효성분은 9
# 유효성분들이 9
# 청주효성병원과 9
# 효성주얼리시티 9
# 효성건설 9
# 안전성ㆍ유효성을 9
# 발효성분인 9
# 전효성을 8
# 유효성분만을 8
# 실효성보다는 8
# 원효성 8
# 효성itx에 8
# 효성과의 8
# 효성대로 8
# 효성이다 7
# 효성가의 7
# 실효성이나 7
# 효성인포메이션시스템은 7
# 효성여대 7
# 효성기술원에서 7
# 꿈의숲효성해링턴플레이스 7
# 효성인상 7
# 효성캐피탈이 7
# 효성굿스프링스는 7
# 효성家 7
# 노틸러스효성과 7
# 효성오앤비에 7
# 유효성의 7
# 안전성ㆍ유효성이 7
# 효성해 7
# 남통효성변압기 7
# 발효성분 7
# 유효성이나 6
# 효성인으로서의 6
# 유효성분에 6
# 효성베트남 6
# 효성빌라는 6
# 효성엔지니어링을 6
# 효성기술원 6
# 효성해링턴스퀘어 6
# 원효성지 6
# 효성만의 6
# 효성창조경제펀드에서 5
# 효성물산은 5

# %%
abc = ['a', 'b', 'c'] #

# %%
stopword_pat_str = '|'.join(stopwords)
print(stopword_pat_str)
# Out:
# 은|을|이|의|에|로|과|도|에서|만|이나|까지|부터|에게|보다|께|처럼|이라도|으로서|조차|만큼|같이|마저|이나마|한테|에게서|께서|이야|이라야|이라야|는|를|가|으로|와|나|라도|로서|나마|더러|한테서

# %%
test_pat_str = '^' + related_company[8] + f'({stopword_pat_str})?'
test_pat = re.compile(test_pat_str)
test_pat
# Out:
# re.compile(r'^효성굿스프링스(은|을|이|의|에|로|과|도|에서|만|이나|까지|부터|에게|보다|께|처럼|이라도|으로서|조차|만큼|같이|마저|이나마|한테|에게서|께서|이야|이라야|이라야|는|를|가|으로|와|나|라도|로서|나마|더러|한테서)?',
# re.UNICODE)

# %%
sss = []
ordered_companies = sorted(related_company, key=lambda a:len(a), reverse=True)

for comp in ordered_companies:
    test_pat_str = '^' + comp + f'({stopword_pat_str})?$'
    test_pat = re.compile(test_pat_str)
    for key, val in freqs:
        if re.match(test_pat, key) is not None:
            sss.append(key)     
sss
# Out:
# ['효성인포메이션시스템은',
#  '효성인포메이션시스템',
#  '효성인포메이션시스템의',
#  '효성인포메이션시스템이',
#  '효성인포메이션시스템을',
#  '효성프리미어모터스',
#  '효성프리미어모터스가',
#  '효성프리미어모터스는',
#  '효성프리미어모터스와',
#  '효성프리미어모터스를',
#  '효성아이티엑스',
#  '효성굿스프링스는',
#  '효성굿스프링스',
#  '효성굿스프링스가',
#  '효성굿스프링스과',
#  '효성굿스프링스와',
#  '더프리미엄효성은',
#  '더프리미엄효성',
#  '더프리미엄효성의',
#  '더클래스효성의',
#  '더클래스효성',
#  '더클래스효성과',
#  '더클래스효성은',
#  '더클래스효성이',
#  '더클래스효성에',
#  '더클래스효성와',
#  '효성투자개발이',
#  '효성투자개발',
#  '효성투자개발에',
#  '효성투자개발은',
#  '효성투자개발을',
#  '효성투자개발과',
#  '효성itx는',
#  '효성itx와',
#  '효성itx',
#  '효성itx가',
#  '효성itx의',
#  '효성itx도',
#  '효성itx를',
#  '효성itx에',
#  '효성itx로',
#  '효성itx은',
#  '효성캐피탈',
#  '효성캐피탈의',
#  '효성캐피탈에',
#  '효성캐피탈을',
#  '효성캐피탈은',
#  '효성캐피탈이',
#  '효성캐피탈과',
#  '효성캐피탈에서',
#  '효성캐피탈도',
#  '효성토요타',
#  '효성토요타도',
#  '효성토요타가',
#  '효성토요타로',
#  '효성토요타의',
#  '효성중공업',
#  '효성중공업은',
#  '효성중공업의',
#  '효성중공업에서',
#  '효성중공업으로',
#  '효성의',
#  '효성을',
#  '효성이',
#  '효성도',
#  '효성에',
#  '효성과',
#  '효성에게',
#  '효성에서',
#  '효성가',
#  '효성으로',
#  '효성처럼',
#  '효성이나',
#  '효성까지']

# %%
ordered_companies = sorted(related_company, key=lambda a:len(a), reverse=True)

patterned_word = ['^'+a+'.*' for a in related_company]

pat_str = '|'.join(related_company)
new_pat = re.compile(pat_str)
new_pat
# Out:
# re.compile(r'효성|더클래스효성|에이에스씨|효성티앤에스|진흥기업|효성아이티엑스|효성itx|에프엠케이|효성굿스프링스|효성캐피탈|효성인포메이션시스템|효성트랜스월드|갤럭시아디바이스|신화인터텍|신성자동차|효성토요타|신동진|갤럭시아커뮤니케이션즈|더프리미엄효성|갤럭시아일렉트로닉스|엔에이치테크|갤럭시아에스엠|엔에이치씨엠에스|갤럭시아코퍼레이션|효성에프엠에스|효성프리미어모터스|아이티엑스마케팅|평창풍력발전|세빛섬|공덕개발|광주일보사|공덕경우개발|트리니티에셋매니지먼트|에이티엠플러스|행복두드리미|태안솔라팜|에브리쇼|동륭실업|아승오토모티브그룹|효성투자개발|효성중공업',
# re.UNICODE)

# %%
re.match(new_pat, '그거더클래스효성이다')

# %%
with open('stopwords.txt', 'r') as fp:
    stopwords = [l.strip() for l in fp.readlines()]
    print(len(stopwords))
# Out:
# 41

# %%
a = re.compile('r.*[a|b|c].*')

# %%
a = re.compile('.*[abc].*')

# %%
asdabc = a.match('uddd')
print(asdabc)
# Out:
# <_sre.SRE_Match object; span=(0, 4), match='uddd'>

# %%
asdabc = a.search('a')

# %%
print(asdabc)
# Out:
# <_sre.SRE_Match object; span=(0, 4), match='uddd'>

# %% [markdown]
# - 명백하게 종목인 단어들 (효성ixt, ...) 포함하면 -> 레이블 1
# - (명백하게 종목인 단어들 + 애매한 단어들 (효성도))을 하나도 포함 안 하는 문장 -> 레이블 0
# - 애매한 단어들, 명백하게 종목이 아닌 단어들 -> 나머지 문장은 노가다....
